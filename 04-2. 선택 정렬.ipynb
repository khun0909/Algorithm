# %% [markdown]
# ##### 선택 정렬선택 정렬(selection sort)
# - 대상 데이터에서 최대나 최소 데이터를 데이터가 나열된 순으로 찾아가며 선택하는 방법이다.
# - 선택 정렬은 구현 방법이 복잡하고, 시간 복잡도도 O(n^2)이다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](attachment:image.png)
