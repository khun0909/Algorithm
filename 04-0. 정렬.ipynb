# %% [markdown]
# #### 정렬 알고리즘(P94)
# - 정렬(Sorting) 이란 데이터를 특정한 기준에 따라 순서대로 나열하는 것
# - 일반적으로 문제 상황에 따라서 적절한 정렬 알고리즘이 공식처럼 사용됨
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 버블 정렬
# - 두 인접한 데이터의 크기를 비교해 정렬하는 방법
# - 간단하게 구현할 순 있지만, 시간 복잡도는 O(n^2)으로 다른 정렬 알고리즘보다 속도가 느리다.
# - 루프loop를 돌면서 인접한 데이터 간의 swap 연산으로 정렬합니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 버블 정렬 과정<br>
# ① 비교 연산이 필요한 루프 범위를 설정한다.<br>
# ② 인접한 데이터 값을 비교한다.<br>
# ③ swap 조건에 부합하면 swap 연산을 수행한다. <br>
# ④ 루프 범위가 끝날 때까지 ②~③을 반복한다.<br>
# ⑤ 정렬 영역을 설정한다. 다음 루프를 실행할 때는 이 영역을 제외한다. <br>
# ⑥ 비교 대상이 없을 때까지 ①~⑤를 반복한다.<br>

# %% [markdown]
# #### 선택 정렬
# - 처리되지 않은 데이터 중에서 가장 작은 데이터를 선택해 맨 앞에 있는 데이터와 바꾸는 것을 반복한다
#
# ![image.png](attachment:image.png)
#
# - 구현 방법이 복잡하고, 시간 복잡도도 O(n^2)으로 효율적이지 않아 코딩 테스트에서는 많이 사용하지 않는다.

# %% [markdown]
# ##### 삽입 정렬
# - 처리되지 않은 데이터를 하나씩 골라 적절한 위치에 삽입한다
# - 선택 정렬에 비해 구현 난이도가 높은 편이지만, 일반적으로 더 효율적으로 동작한다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 퀵 정렬
# - 기준 데이터를 설정하고 그 기준보다 큰 데이터와 작은 데이터의 위치를 바꾸는 방법이다
# - 일반적인 상황에서 가장 많이 사용되는 정렬 알고리즘 중 하나이다
# - 병합 정렬과 더불어 대부분의 프로그래밍 언어의 정렬 라이브러리의 근간이 되는 알고리즘이다
# - 가장 기본적인 퀵 정렬은 첫 번째 데이터를 기준 데이터(Pivot)로 설정한다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 병합 정렬
# - 분할 정복(divide and conquer) 방식을 사용해 데이터를 분할하고 분할한 집합을 정렬하며 합치는 알고리즘
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 두개의 그룹을 병합하는 과정
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 기수 정렬(radix sort)
# - 자리수를 비교해서 정렬하는 방식이다.
# - 단점: 자리수가 없는 것들(부동소수점)은 정렬할 수 없다.(문자열, 정수형 데이터만 적용)
# - 시간복잡도: O(kn), k는 가장 큰 데이터의 자리수(10000 => k:5)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 계수 정렬
# - 값을 비교하지 않는 특이한 정렬
# - 특정한 조건이 부합할 때만 사용할 수 있지만 매우 빠르게 동작하는 정렬 알고리즘이다
#     - 계수 정렬은 데이터의 크기 범위가 제한되어 정수 형태로 표현할 수 있을 때 사용 가능
# - 데이터의 개수가 𝑁, 데이터(양수) 중 최댓값이 𝐾일 때 최악의 경우에도 수행 시간 O(N + K) 를 보장한다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
