# %% [markdown]
# #### 배열과 리스트
# - 평균 구하기(p38)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 계산식: 값3 => (a/m x 100 + b/m x 100 + c/m x 100) / 3 => (a+b+c) x 100 / m / 3
# - 첫번째: 최대값 m = 80  => (40+80+60)x100/80/3

# %% [markdown]
# ##### 슈도코드(글로쓰기)
# - N : 과목수 입력
# - scoreList : 점수 정보 저장
# - maxScore : 점수(scoreList)에서 최대값 저장
# - sum : scoreList의 점수 합계
# - sum x 100 / maxScore / N
# <br>
# - map(int,input('점수입력:').split()) : 한줄로 정수를 각각 입력하여 띄어쓰기를 기준으로 배열을 만들어줌

# %%
list(map(int,input('점수입력:').split()))
# Out:
# [20, 30, 40]

# %%
# 코드 생성
n = int(input('과목수:'))
scoreList = list(map(int,input('점수입력:').split()))
maxScore = max(scoreList)
userSum = sum(scoreList)

print(userSum*100/maxScore/int(n))
# Out:
# 83.33333333333333

# %% [markdown]
# - 추가작업: 수정된 점수와 평균점수 각각의 출에 출력
#     - 기존 점수 scoreList에 수정값 저장60

# %%
# 1. 과목수 입력 => n
# 2. n개의 과목에 대한 점수를 입력받아서 리스트에 저장 => scoreList
# 3. 최고 점수 확인 => maxScore
# 4. 리스트 점수를 이용해 새로운 리스트를 생성 => scoreList
# 5. 새로운 리스트를 이용해 총점과 평균을 계산
# 6. 새로운 점수와 평균 출력

# 코드 생성
n = int(input('과목수:'))
scoreList = list(map(int,input('점수입력:').split()))
maxScore = max(scoreList)

for i in range(n):     # for i in scoreList: (x)
    scoreList[i] = int(scoreList[i]/maxScore*100)
    
userSum = sum(scoreList)

for i in range(n):
    print(scoreList[i])
print(userSum/n)
# Out:
# 69
# 84
# 100
# 63
# 80
# 79.2
