# %% [markdown]
# ### 유니온 파인드(union–find)
# - 일반적으로 여러 노드가 있을 때 특정 2개의 노드를 연결해 1개의 집합으로 묶는 union 연산과 <br>
# 두 노드가 같은 집합에 속해 있는지를 확인하는 find 연산으로 구성되어 있는 알고리즘.
# - 노드들을 합치고(union), 부모를 찾아(find) 서로소 집합(disjoint set)을 찾아내는 알고리즘
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 유니온 파인드를 표현하는 일반적인 방법은 1차원 리스트를 이용한다.
# - 처음에는 노드가 연결되어 있지 않으므로 각 노드가 대표 노드가 된다.
# - 각 노드가 모두 대표 노드이므로 리스트는 자신의 인덱스값으로 초기화 한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 2개의 노드를 선택해 각각의 대표 노드를 찾아 연결하는 union 연산을 수행.
# - 리스트를 보면 1, 4와 5, 6을 union 연산으로 연결.
# - 리스트 6은 5로 업데이트.
#
# ![image.png](attachment:image.png)
#
# - 이제 union(4, 6)으로 4와 6을 연결해 본다.
#     - 4, 6은 대표 노드가 아님. 따라서 각 노드의 대표 노드를 찾아 올라간 다음 그 대표 노드를 연결한다
#     - 4의 대표 노드 1에 6의 대표 노드 5를 연결한 것
# - 리스트는 그럼 [1, 2, 3, 1, 1, 5]가 된다

# %% [markdown]
# 3. find 연산은 자신이 속한 집합의 대표 노드를 찾는 연산이다.
# - find 연산은 단순히 대표 노드를 찾는 역할만 하는 것이 아니라 그래프를 정돈하고 시간 복잡도를 줄인다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - find 연산 속도가 O(1)로 변경 된다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### [문제] 집합 표현하기
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 문제 풀이
# 1. 처음에는 노드가 연결돼 있지 않으므로 각 노드의 대표 노드는 자기 자신이다.
# - 각 노드의 값을 자기 인덱스값으로 초기화 한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. find 연산으로 특정 노드의 대표 노드를 찾고, union 연산으로 2개의 노드를 이용해 각 대표 노드를 찾아 연결하고 질의한 값에 따라 결과를 반환한다.
#
# ![image.png](attachment:image.png)

# %%
# 코드 입력
