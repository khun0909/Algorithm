# %% [markdown]
# ##### 버블 정렬(bubble sort)
# - 두 인접한 데이터의 크기를 비교해 정렬하는 방법이다.
# - 간단하게 구현할 순 있지만, 시간 복잡도는 O(n2)으로 다른 정렬 알고리즘보다 속도가 느린 편이다.
# - 루프loop를 돌면서 인접한 데이터 간의 swap 연산으로 정렬한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 수 정렬하기(제한시간 2초)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
