# %% [markdown]
# ##### 오일러 피 함수(P[N])
# - 오일러 피 함수 P[N]의 정의는 1부터 N까지 범위에서 N과 서로소인 자연수의 개수를 뜻한다.
#
# - 1~n까지의 수 중에서 n과 서로소인 수의 갯수<br>
# ※ 서로소 관계: 두 수 a, b의 공약수가 1뿐인 두 정수를 의미한다.
#     - ϕ(1) = 1 (1은 1과 서로소)
#     - ϕ(6) = {1, 5}  = 2개 (3은 3과 서로소)
#     - ϕ(8) = { 1, 3, 5, 7 } = 4개
#     - ϕ(13) = = 12개
#     - ϕ(13) = = 12개
#     - ϕ(15) = = 8개
#
# 참조: https://zoosso.tistory.com/243

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 오일러 피 함수 원리
# 1. 구하고자 하는 범위까지 리스트를 생성한 후 2를 선택한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 2의 모든 배수마다 P[i] = P[i] - P[i] / 2 연산을 수행해 값을 갱신한다. <br>
# 예를 들어 8 = 8 – (8 / 2)를 통해 4를 계산한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 소수 구하기에서 배수를 지우는 부분만 P[i] = P[i] - P[i] / K로 변경하면 오일러 피 함수를 간단히 구현할 수 있다.
# <br>탐색을 계속 진행하면서 N = ∮(N)인 곳(소수)을 찾아 값을 갱신한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. 리스트가 끝날 때까지 반복한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 오일러 피 함수 구현 문제
# - 자연수 n이 주어졌을 때 GCD(n, k) = 1(1 ≤ k ≤ n)을 만족하는 자연수의 개수를 구하는 프로그램을 작성하시오.
#
# ![image.png](attachment:image.png)
#
# - 문제에서 요구하는 GCD(n, k) = 1을 만족하는 자연수의 개수가 바로 오일러 피 함수의 정의이다. <br>
# 즉, 오일러 피 함수를 잘 구현할 수 있는지 묻는 문제이다.

# %% [markdown]
# 1. 서로소의 개수를 표현하는 변수 result와 현재 소인수 구성을 표시하는 변수 n을 선언한다. <br>
# 예제 입력 4의 경우 변수 초기화는 n = 45, result = 45로 합니다.<br><br>
# 2. 오일러 피 핵심 이론 부분을 참고해 2 ~ N의 제곱근까지 탐색하면서 소인수일 때 result = result – (result / 소인수) 연산으로 result값을 업데이트한다. <br>
# 이때 n에서 이 소인수는 나누기 연산으로 삭제한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 반복문 종료 후 현재 n이 1보다 크면 n이 마지막 소인수라는 뜻이다. <br>
# result = result – (result / n) 연산으로 result값을 마지막으로 업데이트한 후 출력한다.
#
# ![image.png](attachment:image.png)

# %%
# 코드 입력
