# %% [markdown]
# ##### 병합 정렬(merge sort)
# - 분할 정복(divide and conquer) 방식을 사용해 데이터를 분할하고 분할한 집합을 정렬하며 합치는 알고리즘
# - 병합 정렬의 시간 복잡도:  O(nlogn)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 수 정렬2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 풀이 방법
# 1. 정렬그룹을 최소 길이로 나눈다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 그룹이 3개이므로 2번째/3번째 그룹 병합
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 병합된 그룹을 정렬한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 마지막 정렬 결과
#
# ![image.png](attachment:image.png)
